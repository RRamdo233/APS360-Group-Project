# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import os

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
torch.backends.cudnn.benchmark = True
# Out:
# cuda:0

# %%
runs_list = next(os.walk('./Data/Images'))[1]

# %%
path = "./Data/Labels.csv"
header = ['Run','AD']
Labelsdf = pd.read_csv(path, names=header, usecols=[1,2], skiprows=1, index_col=False)

# %%
labels_dict = dict(zip(Labelsdf.Run, Labelsdf.AD))

# %%
len(runs_list)
# Out:
# 3386

# %%
runs_list = runs_list[:700]

# %%
len(runs_list)
# Out:
# 700

# %%
import re

# BellCNN takes in images of size 208x176x1
# Crop in the x and y direction (get center/hippocampi area)
# [24:232,:]
# arbitrarily select the depth slice? (average from 130 5o 170)

img_dir = "./Data/Images"
dest_dir = "./Data/Processed"

if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)
    print("Created ouput directory: " + dest_dir)

#low_bound = 100
#high_bound = 200
#img_scale = 1
depth_scale = 21

#list of tuples (image data, AD)
train_data, valid_data, test_data = [], [], []
for run in runs_list:
    #print(run)
    run_dir = os.path.join(img_dir, run)
    run_imgs = []
    for filename in os.listdir(run_dir):
        img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
        if  img_slice is None or img_slice.shape[0] != 256 or img_slice.shape[1] != 176:
            print(run)
            break
        img_num = int(filename[-7:-4])
        if (140 <= img_num < 161):
            img_slice = cv2.imread(os.path.join(run_dir, filename), cv2.IMREAD_GRAYSCALE)
            #img_slice = cv2.resize(img_slice, (0,0), fx=1/img_scale, fy=1/img_scale, interpolation=cv2.INTER_AREA)
            img_slice = img_slice[24:232,:]
            # normalize pixel intensity to range of 0 and 1
            img_slice = img_slice/256
            run_imgs.append(img_slice)

    if len(run_imgs) == 0 or len(run_imgs) != 21:
        print(run)
        continue
            
    temp_arr = np.array(run_imgs)
    
    final_slices = []
    #print(temp_arr.shape[2])
    
    for y in range(temp_arr.shape[2]):
        xz_pane = temp_arr[:, :, y]
        scaled_xz = cv2.resize(xz_pane, (0, 0), fy=1/depth_scale, fx=1, interpolation=cv2.INTER_AREA)
        final_slices.append(scaled_xz)
    
    if not len(final_slices[0]) == 1:
        print(run)
        continue
    
    final_slices = np.dstack(final_slices)
    #final_slices = np.expand_dims(final_slices, axis=0)
    #final_array = torch.from_numpy(np.dstack(final_slices)).float()
    #print(final_array.shape)
    if run in labels_dict:
        # save as binary
        np.save(os.path.join(dest_dir, run), final_slices)
        run_tuple = (run, labels_dict[run])
    else:
        continue
    
    subject_regex = re.compile("OAS(?P<order>[0-9]+)")
    subject = subject_regex.search(run).group(1)
    
    if int(subject[-1]) < 6:
        train_data.append(run_tuple)
    elif 6 <= int(subject[-1]) <=7:
        valid_data.append(run_tuple)
    elif 8 <= int(subject[-1]) <= 9:
        test_data.append(run_tuple)
    
    
    
    
print("Number of data points in train dataset: {}".format(len(train_data)))
print("Number of data points in valid dataset: {}".format(len(valid_data)))
print("Number of data points in test dataset: {}".format(len(test_data)))
# Out:
# sub-OAS30001_ses-d2430
# sub-OAS30001_ses-d2430
# sub-OAS30002_ses-d0371
# sub-OAS30002_ses-d0371
# sub-OAS30002_ses-d2340_run-01
# sub-OAS30002_ses-d2340_run-01
# sub-OAS30003_ses-d2682
# sub-OAS30003_ses-d2682
# sub-OAS30003_ses-d3731
# sub-OAS30003_ses-d3731
# sub-OAS30004_ses-d2232_run-01
# sub-OAS30004_ses-d2232_run-01
# sub-OAS30004_ses-d3457
# sub-OAS30004_ses-d3457
# sub-OAS30005_ses-d0143
# sub-OAS30005_ses-d0143
# sub-OAS30005_ses-d2384
# sub-OAS30005_ses-d2384
# sub-OAS30005_ses-d3453
# sub-OAS30005_ses-d3453
# sub-OAS30006_ses-d0166
# sub-OAS30006_ses-d0166
# sub-OAS30006_ses-d2342
# sub-OAS30006_ses-d2342
# sub-OAS30006_ses-d3386
# sub-OAS30006_ses-d3386
# sub-OAS30007_ses-d1636
# sub-OAS30007_ses-d1636
# sub-OAS30007_ses-d2722
# sub-OAS30007_ses-d2722
# sub-OAS30008_ses-d1313
# sub-OAS30008_ses-d1313
# sub-OAS30008_ses-d1327
# sub-OAS30008_ses-d1327
# sub-OAS30008_ses-d2035
# sub-OAS30008_ses-d2035
# sub-OAS30010_ses-d0068
# sub-OAS30010_ses-d0068
# sub-OAS30011_ses-d1671
# sub-OAS30011_ses-d1671
# sub-OAS30012_ses-d0124_run-01
# sub-OAS30012_ses-d0124_run-01
# sub-OAS30012_ses-d0124_run-02
# sub-OAS30012_ses-d0124_run-02
# sub-OAS30012_ses-d0124_run-03
# sub-OAS30012_ses-d0124_run-03
# sub-OAS30012_ses-d0581_run-01
# sub-OAS30012_ses-d0581_run-01
# sub-OAS30012_ses-d0581_run-02
# sub-OAS30012_ses-d0581_run-02
# sub-OAS30012_ses-d0581_run-03
# sub-OAS30012_ses-d0581_run-03
# sub-OAS30013_ses-d0102
# sub-OAS30013_ses-d0102
# sub-OAS30020_ses-d0092_run-01
# sub-OAS30020_ses-d0092_run-01
# sub-OAS30020_ses-d0092_run-02
# sub-OAS30020_ses-d0092_run-02
# sub-OAS30020_ses-d0092_run-03
# sub-OAS30020_ses-d0092_run-03
# sub-OAS30020_ses-d0092_run-04
# sub-OAS30020_ses-d0092_run-04
# sub-OAS30020_ses-d0911_run-01
# sub-OAS30020_ses-d0911_run-01
# sub-OAS30020_ses-d0911_run-02
# sub-OAS30020_ses-d0911_run-02
# sub-OAS30020_ses-d0911_run-03
# sub-OAS30020_ses-d0911_run-03
# sub-OAS30021_ses-d0071
# sub-OAS30021_ses-d0071
# sub-OAS30022_ses-d1324_run-01
# sub-OAS30022_ses-d1324_run-01
# sub-OAS30022_ses-d1324_run-02
# sub-OAS30022_ses-d1324_run-02
# sub-OAS30022_ses-d1324_run-03
# sub-OAS30022_ses-d1324_run-03
# sub-OAS30024_ses-d0084
# sub-OAS30024_ses-d0084
# sub-OAS30025_ses-d0210_run-02
# sub-OAS30025_ses-d0210_run-02
# sub-OAS30025_ses-d2298
# sub-OAS30025_ses-d2298
# sub-OAS30026_ses-d0129
# sub-OAS30026_ses-d0129
# sub-OAS30026_ses-d0696
# sub-OAS30026_ses-d0696
# sub-OAS30028_ses-d1260
# sub-OAS30028_ses-d1260
# sub-OAS30028_ses-d1847
# sub-OAS30028_ses-d1847
# sub-OAS30032_ses-d0262_run-01
# sub-OAS30032_ses-d0262_run-01
# sub-OAS30032_ses-d0262_run-02
# sub-OAS30032_ses-d0262_run-02
# sub-OAS30032_ses-d0262_run-03
# sub-OAS30032_ses-d0262_run-03
# sub-OAS30038_ses-d1214_run-01
# sub-OAS30038_ses-d1214_run-01
# sub-OAS30038_ses-d1214_run-02
# sub-OAS30038_ses-d1214_run-02
# sub-OAS30038_ses-d1214_run-03
# sub-OAS30038_ses-d1214_run-03
# sub-OAS30039_ses-d0103
# sub-OAS30039_ses-d0103
# sub-OAS30040_ses-d2899_run-01
# sub-OAS30040_ses-d2899_run-01
# sub-OAS30040_ses-d2899_run-02
# sub-OAS30040_ses-d2899_run-02
# sub-OAS30040_ses-d2899_run-03
# sub-OAS30040_ses-d2899_run-03
# sub-OAS30041_ses-d6548_run-01
# sub-OAS30041_ses-d6548_run-01
# sub-OAS30041_ses-d6548_run-02
# sub-OAS30041_ses-d6548_run-02
# sub-OAS30041_ses-d6548_run-03
# sub-OAS30041_ses-d6548_run-03
# sub-OAS30041_ses-d6548_run-04
# sub-OAS30041_ses-d6548_run-04
# sub-OAS30041_ses-d6548_run-05
# sub-OAS30041_ses-d6548_run-05
# sub-OAS30042_ses-d0067
# sub-OAS30042_ses-d0067
# sub-OAS30044_ses-d0061_run-01
# sub-OAS30044_ses-d0061_run-01
# sub-OAS30044_ses-d0061_run-02
# sub-OAS30044_ses-d0061_run-02
# sub-OAS30044_ses-d1319
# sub-OAS30044_ses-d1319
# sub-OAS30046_ses-d1968
# sub-OAS30046_ses-d1968
# sub-OAS30048_ses-d0983_run-01
# sub-OAS30048_ses-d0983_run-01
# sub-OAS30048_ses-d0983_run-02
# sub-OAS30048_ses-d0983_run-02
# sub-OAS30048_ses-d0983_run-03
# sub-OAS30048_ses-d0983_run-03
# sub-OAS30048_ses-d3375_run-01
# sub-OAS30048_ses-d3375_run-01
# sub-OAS30048_ses-d3731
# sub-OAS30048_ses-d3731
# sub-OAS30049_ses-d1633
# sub-OAS30049_ses-d1633
# sub-OAS30050_ses-d1530
# sub-OAS30050_ses-d1530
# sub-OAS30052_ses-d2737_run-01
# sub-OAS30052_ses-d2737_run-01
# sub-OAS30052_ses-d2737_run-02
# sub-OAS30052_ses-d2737_run-02
# sub-OAS30056_ses-d3491
# sub-OAS30056_ses-d3491
# sub-OAS30057_ses-d0075
# sub-OAS30057_ses-d0075
# sub-OAS30059_ses-d0230_run-01
# sub-OAS30059_ses-d0230_run-01
# sub-OAS30059_ses-d0230_run-02
# sub-OAS30059_ses-d0230_run-02
# sub-OAS30059_ses-d0230_run-03
# sub-OAS30059_ses-d0230_run-03
# sub-OAS30059_ses-d0230_run-04
# sub-OAS30059_ses-d0230_run-04
# sub-OAS30059_ses-d1188
# sub-OAS30059_ses-d1188
# sub-OAS30062_ses-d0087_run-01
# sub-OAS30062_ses-d0087_run-01
# sub-OAS30062_ses-d0087_run-02
# sub-OAS30062_ses-d0087_run-02
# sub-OAS30062_ses-d0087_run-03
# sub-OAS30062_ses-d0087_run-03
# sub-OAS30065_ses-d2009
# sub-OAS30065_ses-d2009
# sub-OAS30066_ses-d2006
# sub-OAS30066_ses-d2006
# sub-OAS30068_ses-d0076
# sub-OAS30068_ses-d0076
# sub-OAS30071_ses-d0018
# sub-OAS30071_ses-d0018
# sub-OAS30072_ses-d0218_run-01
# sub-OAS30072_ses-d0218_run-01
# sub-OAS30072_ses-d0218_run-02
# sub-OAS30072_ses-d0218_run-02
# sub-OAS30072_ses-d0218_run-03
# sub-OAS30072_ses-d0218_run-03
# sub-OAS30073_ses-d0033_run-01
# sub-OAS30073_ses-d0033_run-01
# sub-OAS30073_ses-d0033_run-02
# sub-OAS30073_ses-d0033_run-02
# sub-OAS30073_ses-d0033_run-03
# sub-OAS30073_ses-d0033_run-03
# sub-OAS30073_ses-d0033_run-04
# sub-OAS30073_ses-d0033_run-04
# sub-OAS30073_ses-d4456
# sub-OAS30073_ses-d4456
# sub-OAS30075_ses-d0148_run-01
# sub-OAS30075_ses-d0148_run-01
# sub-OAS30075_ses-d0442
# sub-OAS30075_ses-d0442
# sub-OAS30075_ses-d0967
# sub-OAS30075_ses-d0967
# sub-OAS30080_ses-d1318
# sub-OAS30080_ses-d1318
# sub-OAS30083_ses-d2882
# sub-OAS30083_ses-d2882
# sub-OAS30083_ses-d3827
# sub-OAS30083_ses-d3827
# sub-OAS30089_ses-d0001
# sub-OAS30089_ses-d0001
# sub-OAS30090_ses-d1294
# sub-OAS30090_ses-d1294
# sub-OAS30092_ses-d0636
# sub-OAS30092_ses-d0636
# sub-OAS30093_ses-d0056
# sub-OAS30093_ses-d0056
# sub-OAS30093_ses-d1192
# sub-OAS30093_ses-d1192
# sub-OAS30094_ses-d0140_run-01
# sub-OAS30094_ses-d0140_run-01
# sub-OAS30094_ses-d0140_run-02
# sub-OAS30094_ses-d0140_run-02
# sub-OAS30094_ses-d0140_run-03
# sub-OAS30094_ses-d0140_run-03
# sub-OAS30094_ses-d0679_run-01
# sub-OAS30094_ses-d0679_run-01
# sub-OAS30094_ses-d0679_run-02
# sub-OAS30094_ses-d0679_run-02
# sub-OAS30094_ses-d0679_run-03
# sub-OAS30094_ses-d0679_run-03
# sub-OAS30097_ses-d2551
# sub-OAS30097_ses-d2551
# sub-OAS30098_ses-d0036
# sub-OAS30098_ses-d0036
# sub-OAS30100_ses-d0158
# sub-OAS30100_ses-d0158
# sub-OAS30101_ses-d2650
# sub-OAS30101_ses-d2650
# sub-OAS30102_ses-d0024
# sub-OAS30102_ses-d0024
# sub-OAS30103_ses-d3306_run-01
# sub-OAS30103_ses-d3306_run-01
# sub-OAS30103_ses-d3306_run-02
# sub-OAS30103_ses-d3306_run-02
# sub-OAS30103_ses-d3306_run-03
# sub-OAS30103_ses-d3306_run-03
# sub-OAS30105_ses-d0056
# sub-OAS30105_ses-d0056
# sub-OAS30106_ses-d2982_run-01
# sub-OAS30106_ses-d2982_run-01
# sub-OAS30106_ses-d2982_run-02
# sub-OAS30106_ses-d2982_run-02
# sub-OAS30106_ses-d2982_run-03
# sub-OAS30106_ses-d2982_run-03
# sub-OAS30108_ses-d2066
# sub-OAS30108_ses-d2066
# sub-OAS30109_ses-d0270
# sub-OAS30109_ses-d0270
# sub-OAS30109_ses-d2320
# sub-OAS30109_ses-d2320
# sub-OAS30112_ses-d0098
# sub-OAS30112_ses-d0098
# sub-OAS30112_ses-d1196
# sub-OAS30112_ses-d1196
# sub-OAS30113_ses-d0894
# sub-OAS30113_ses-d0894
# sub-OAS30113_ses-d4437
# sub-OAS30113_ses-d4437
# sub-OAS30114_ses-d0086
# sub-OAS30114_ses-d0086
# sub-OAS30117_ses-d4155
# sub-OAS30117_ses-d4155
# sub-OAS30118_ses-d0000_run-01
# sub-OAS30118_ses-d0000_run-01
# sub-OAS30118_ses-d0000_run-02
# sub-OAS30118_ses-d0000_run-02
# sub-OAS30118_ses-d0000_run-03
# sub-OAS30118_ses-d0000_run-03
# sub-OAS30119_ses-d1209_run-01
# sub-OAS30119_ses-d1209_run-01
# sub-OAS30119_ses-d1209_run-02
# sub-OAS30119_ses-d1209_run-02
# sub-OAS30119_ses-d1209_run-03
# sub-OAS30119_ses-d1209_run-03
# sub-OAS30120_ses-d0784_run-01
# sub-OAS30120_ses-d0784_run-01
# sub-OAS30120_ses-d0784_run-02
# sub-OAS30120_ses-d0784_run-02
# sub-OAS30120_ses-d0784_run-03
# sub-OAS30120_ses-d0784_run-03
# sub-OAS30120_ses-d0784_run-04
# sub-OAS30120_ses-d0784_run-04
# sub-OAS30121_ses-d0768_run-01
# sub-OAS30121_ses-d0768_run-01
# sub-OAS30121_ses-d0768_run-02
# sub-OAS30121_ses-d0768_run-02
# sub-OAS30121_ses-d0768_run-03
# sub-OAS30121_ses-d0768_run-03
# sub-OAS30121_ses-d0768_run-04
# sub-OAS30121_ses-d0768_run-04
# sub-OAS30122_ses-d0136
# sub-OAS30122_ses-d0136
# sub-OAS30123_ses-d0122
# sub-OAS30123_ses-d0122
# sub-OAS30126_ses-d3465
# sub-OAS30126_ses-d3465
# sub-OAS30127_ses-d0110
# sub-OAS30127_ses-d0110
# sub-OAS30127_ses-d0837
# sub-OAS30127_ses-d0837
# sub-OAS30128_ses-d0044
# sub-OAS30128_ses-d0044
# sub-OAS30129_ses-d0055
# sub-OAS30129_ses-d0055
# sub-OAS30131_ses-d0086_run-01
# sub-OAS30131_ses-d0086_run-01
# sub-OAS30131_ses-d0086_run-02
# sub-OAS30131_ses-d0086_run-02
# sub-OAS30131_ses-d0086_run-03
# sub-OAS30131_ses-d0086_run-03
# sub-OAS30131_ses-d0632_run-01
# sub-OAS30131_ses-d0632_run-01
# sub-OAS30131_ses-d0632_run-02
# sub-OAS30131_ses-d0632_run-02
# sub-OAS30131_ses-d0632_run-03
# sub-OAS30131_ses-d0632_run-03
# sub-OAS30134_ses-d1642
# sub-OAS30134_ses-d1642
# sub-OAS30135_ses-d0190
# sub-OAS30135_ses-d0190
# sub-OAS30135_ses-d2367
# sub-OAS30135_ses-d2367
# sub-OAS30135_ses-d2931
# sub-OAS30135_ses-d2931
# sub-OAS30139_ses-d1702
# sub-OAS30139_ses-d1702
# sub-OAS30143_ses-d3509
# sub-OAS30143_ses-d3509
# sub-OAS30143_ses-d4041
# sub-OAS30143_ses-d4041
# sub-OAS30144_ses-d1204_run-01
# sub-OAS30144_ses-d1204_run-01
# sub-OAS30144_ses-d1204_run-02
# sub-OAS30144_ses-d1204_run-02
# sub-OAS30144_ses-d1204_run-03
# sub-OAS30144_ses-d1204_run-03
# sub-OAS30149_ses-d1240
# sub-OAS30149_ses-d1240
# sub-OAS30151_ses-d0064
# sub-OAS30151_ses-d0064
# sub-OAS30153_ses-d2220_run-01
# sub-OAS30153_ses-d2220_run-01
# sub-OAS30153_ses-d2220_run-02
# sub-OAS30153_ses-d2220_run-02
# sub-OAS30153_ses-d2220_run-03
# sub-OAS30153_ses-d2220_run-03
# sub-OAS30153_ses-d2220_run-04
# sub-OAS30153_ses-d2220_run-04
# sub-OAS30155_ses-d0785
# sub-OAS30155_ses-d0785
# sub-OAS30156_ses-d0000_run-01
# sub-OAS30156_ses-d0000_run-01
# sub-OAS30156_ses-d0000_run-02
# sub-OAS30156_ses-d0000_run-02
# sub-OAS30156_ses-d0000_run-03
# sub-OAS30156_ses-d0000_run-03
# sub-OAS30157_ses-d0889_run-01
# sub-OAS30157_ses-d0889_run-01
# sub-OAS30157_ses-d0889_run-02
# sub-OAS30157_ses-d0889_run-02
# sub-OAS30157_ses-d0889_run-03
# sub-OAS30157_ses-d0889_run-03
# sub-OAS30157_ses-d1428_run-01
# sub-OAS30157_ses-d1428_run-01
# sub-OAS30157_ses-d1428_run-02
# sub-OAS30157_ses-d1428_run-02
# sub-OAS30157_ses-d1428_run-03
# sub-OAS30157_ses-d1428_run-03
# sub-OAS30159_ses-d0110
# sub-OAS30159_ses-d0110
# sub-OAS30167_ses-d1340
# sub-OAS30167_ses-d1340
# sub-OAS30173_ses-d3841
# sub-OAS30173_ses-d3841
# sub-OAS30178_ses-d0049
# sub-OAS30178_ses-d0049
# sub-OAS30178_ses-d2455_run-01
# sub-OAS30178_ses-d2455_run-01
# sub-OAS30178_ses-d2794
# sub-OAS30178_ses-d2794
# sub-OAS30181_ses-d0058
# sub-OAS30181_ses-d0058
# sub-OAS30182_ses-d0101
# sub-OAS30182_ses-d0101
# sub-OAS30182_ses-d1397
# sub-OAS30182_ses-d1397
# sub-OAS30184_ses-d3157
# sub-OAS30184_ses-d3157
# sub-OAS30185_ses-d4551
# sub-OAS30185_ses-d4551
# sub-OAS30187_ses-d0070
# sub-OAS30187_ses-d0070
# sub-OAS30188_ses-d0246_run-01
# sub-OAS30188_ses-d0246_run-01
# sub-OAS30188_ses-d0246_run-02
# sub-OAS30188_ses-d0246_run-02
# sub-OAS30188_ses-d0246_run-03
# sub-OAS30188_ses-d0246_run-03
# sub-OAS30192_ses-d0293_run-01
# sub-OAS30192_ses-d0293_run-01
# sub-OAS30192_ses-d0293_run-02
# sub-OAS30192_ses-d0293_run-02
# sub-OAS30192_ses-d0293_run-03
# sub-OAS30192_ses-d0293_run-03
# sub-OAS30194_ses-d5837_run-01
# sub-OAS30194_ses-d5837_run-01
# sub-OAS30194_ses-d5837_run-02
# sub-OAS30194_ses-d5837_run-02
# sub-OAS30194_ses-d5837_run-03
# sub-OAS30194_ses-d5837_run-03
# sub-OAS30194_ses-d6419_run-01
# sub-OAS30194_ses-d6419_run-01
# sub-OAS30194_ses-d6419_run-02
# sub-OAS30194_ses-d6419_run-02
# sub-OAS30194_ses-d6419_run-03
# sub-OAS30194_ses-d6419_run-03
# sub-OAS30194_ses-d8874
# sub-OAS30194_ses-d8874
# sub-OAS30194_ses-d9443
# sub-OAS30194_ses-d9443
# sub-OAS30195_ses-d0193
# sub-OAS30195_ses-d0193
# sub-OAS30197_ses-d0115
# sub-OAS30197_ses-d0115
# sub-OAS30203_ses-d0203_run-01
# sub-OAS30203_ses-d0203_run-01
# sub-OAS30203_ses-d0203_run-02
# sub-OAS30203_ses-d0203_run-02
# sub-OAS30203_ses-d0203_run-03
# sub-OAS30203_ses-d0203_run-03
# sub-OAS30203_ses-d0802_run-01
# sub-OAS30203_ses-d0802_run-01
# sub-OAS30203_ses-d0802_run-02
# sub-OAS30203_ses-d0802_run-02
# sub-OAS30203_ses-d0802_run-03
# sub-OAS30203_ses-d0802_run-03
# sub-OAS30203_ses-d0802_run-04
# sub-OAS30203_ses-d0802_run-04
# sub-OAS30203_ses-d0802_run-05
# sub-OAS30203_ses-d0802_run-05
# sub-OAS30204_ses-d0033_run-01
# sub-OAS30204_ses-d0033_run-01
# sub-OAS30206_ses-d3024
# sub-OAS30206_ses-d3024
# sub-OAS30208_ses-d1703
# sub-OAS30208_ses-d1703
# sub-OAS30210_ses-d0047
# sub-OAS30210_ses-d0047
# sub-OAS30212_ses-d3043
# sub-OAS30212_ses-d3043
# sub-OAS30213_ses-d0041
# sub-OAS30213_ses-d0041
# sub-OAS30216_ses-d2849_run-01
# sub-OAS30216_ses-d2849_run-01
# sub-OAS30216_ses-d2849_run-02
# sub-OAS30216_ses-d2849_run-02
# sub-OAS30216_ses-d2849_run-03
# sub-OAS30216_ses-d2849_run-03
# sub-OAS30217_ses-d0077
# sub-OAS30217_ses-d0077
# sub-OAS30219_ses-d1184
# sub-OAS30219_ses-d1184
# sub-OAS30220_ses-d1165
# sub-OAS30220_ses-d1165
# sub-OAS30221_ses-d1143
# sub-OAS30221_ses-d1143
# sub-OAS30225_ses-d0482
# sub-OAS30225_ses-d0482
# sub-OAS30228_ses-d0090
# sub-OAS30228_ses-d0090
# sub-OAS30229_ses-d0101
# sub-OAS30229_ses-d0101
# sub-OAS30230_ses-d3855
# sub-OAS30230_ses-d3855
# sub-OAS30231_ses-d1469
# sub-OAS30231_ses-d1469
# sub-OAS30231_ses-d3630
# sub-OAS30231_ses-d3630
# sub-OAS30233_ses-d5295
# sub-OAS30233_ses-d5295
# sub-OAS30234_ses-d1119_run-01
# sub-OAS30234_ses-d1119_run-01
# sub-OAS30234_ses-d1119_run-02
# sub-OAS30234_ses-d1119_run-02
# sub-OAS30234_ses-d1119_run-03
# sub-OAS30234_ses-d1119_run-03
# sub-OAS30235_ses-d0139
# sub-OAS30235_ses-d0139
# sub-OAS30237_ses-d1353_run-01
# sub-OAS30237_ses-d1353_run-01
# sub-OAS30237_ses-d1353_run-02
# sub-OAS30237_ses-d1353_run-02
# sub-OAS30237_ses-d1353_run-03
# sub-OAS30237_ses-d1353_run-03
# sub-OAS30240_ses-d0865_run-01
# sub-OAS30240_ses-d0865_run-01
# Number of data points in train dataset: 276
# Number of data points in valid dataset: 86
# Number of data points in test dataset: 87

# %%
print(type(img_slice))

# %%
from collections import Counter

counts = Counter(x[1] for x in train_data)
print("Number of non-AD scans in train dataset: {}".format(counts[0]))
print("Number of AD scan in train datasets: {}".format(counts[1]))
print("\n")

counts = Counter(x[1] for x in valid_data)
print("Number of non-AD scans in valid dataset: {}".format(counts[0]))
print("Number of AD scan in valid datasets: {}".format(counts[1]))
print("\n")

counts = Counter(x[1] for x in test_data)
print("Number of non-AD scans in test dataset: {}".format(counts[0]))
print("Number of AD scan in test datasets: {}".format(counts[1]))
print("\n")
# Out:
# Number of non-AD scans in train dataset: 246
# Number of AD scan in train datasets: 30
#
#
# Number of non-AD scans in valid dataset: 73
# Number of AD scan in valid datasets: 13
#
#
# Number of non-AD scans in test dataset: 66
# Number of AD scan in test datasets: 21

# %%
old_train_data = train_data
train_AD = []
for item in train_data:
    if item[1] == 1:
        train_AD.append(item)
train_data = old_train_data + train_AD * 4

print("Number of data points in new train dataset: {}".format(len(train_data)))
counts = Counter(x[1] for x in train_data)
print("Number of non-AD scans in new train dataset: {}".format(counts[0]))
print("Number of AD scan in new train dataset: {}".format(counts[1]))
# Out:
# Number of data points in new train dataset: 396
# Number of non-AD scans in new train dataset: 246
# Number of AD scan in new train dataset: 150

# %%
from torch.utils.data import Dataset, DataLoader

class T1Dataset(Dataset):
    def __init__(self, data, transform=None):
        # list of tuples (3d image arrays, AD label)
        self.data = data
        # labels.csv
        #self.target = torch.from_numpy(target).long()
        #self.transform = transforms.Compose([transforms.ToTensor()])
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        #scan = torch.from_numpy(self.data[index][0]).float()
        scan = np.load(os.path.join(dest_dir, self.data[index][0]) + ".npy")
        scan = torch.from_numpy(scan).float()
        y = self.data[index][1]
        return scan, y

# %%
train_dataset = T1Dataset(train_data, None)
valid_dataset = T1Dataset(valid_data, None)
test_dataset = T1Dataset(test_data, None)

# %%
def get_model_name(name, batch_size, learning_rate, epoch):
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

def get_loss(model, train=False):
    model.eval()
    if train:
        data = train_dataset
    else:
        data = valid_dataset
        
    loader = torch.utils.data.DataLoader(data, batch_size=16, shuffle=True)
    criterion = nn.CrossEntropyLoss()
    
    loss = 0
    i = 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        out = model(imgs)             # forward pass
        loss += criterion(out, labels) # compute the total loss
        i += 1
    return loss.item()/i

def get_accuracy(model, train=False):
    model.eval()
    if train:
        data = train_dataset
    else:
        #data_acc_loader = torch.utils.data.DataLoader(data_val, batch_size=diff)
        data = valid_dataset

    correct = 0
    total = 0
    for imgs, labels in torch.utils.data.DataLoader(data, batch_size=16, shuffle=True):
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs) # We don't need to run F.softmax
        pred = outputs.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    #print(total)
    return correct / total

# %%
train_loader = torch.utils.data.DataLoader(test_dataset, batch_size=4, shuffle=True)
imgs, labels = next(iter(train_loader))
print(imgs.size())
print(imgs[0].squeeze(0).size())
scan = imgs[0].squeeze(0).numpy()
print(scan.shape)
plt.imshow(scan)
plt.show()

# %%
def train(model, features_list, num_epochs=2, batch_size=16, learning_rate=1e-4):
    criterion = nn.CrossEntropyLoss()
    # use Adam for CNN
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    epochs, train_losses, valid_losses, train_acc, valid_acc = [], [], [], [], []
    
    train_loader = torch.utils.data.DataLoader(features_list, batch_size=batch_size, shuffle=True)
    
    loss = 0
    
    for epoch in range(num_epochs):
        for inputs, labels in iter(train_loader):
            model.train()
            optimizer.zero_grad()
            inputs, labels = inputs.to(device), labels.to(device)
            #print(torch.sum(inputs))
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward(retain_graph=True)
            optimizer.step()
            #for param in model.parameters():
            #  print(param.grad.data.sum())
    
        epochs.append(epoch)
        #train_losses.append(loss)
        train_losses.append(get_loss(model, train=True))
        valid_losses.append(get_loss(model, train=False))
        train_acc.append(get_accuracy(model, train=True))
        valid_acc.append(get_accuracy(model, train=False))
        
        if epoch % 10 == 0:
            print("Epoch %d; Train Loss %f; Val Loss %f; Train Acc %f; Val Acc %f" % (
                  epoch+1, loss, valid_losses[-1], train_acc[-1], valid_acc[-1]))
            #print(loss)
    
    plt.title("Training Curve")
    plt.plot(epochs, train_losses, label="Train")
    plt.plot(epochs, valid_losses, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

    plt.title("Training Curve")
    plt.plot(epochs, train_acc, label="Train")
    plt.plot(epochs, valid_acc, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()
    
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(valid_acc[-1]))

# %%
class BellCNN(nn.Module):
    def __init__(self):
        super(BellCNN, self).__init__()
        self.name = "BellCNN"
        
        # first block
        # paper says stride is 5??!? Did they mean kernel is 5 or stride for max pool is 5?
        self.conv = nn.Conv2d(1, 32, padding=1, kernel_size=3)
        self.maxpool = nn.MaxPool2d(kernel_size=(3,1), stride=5)
        
        # second block
        self.conv_1 = nn.Conv2d(32, 64, padding=1, kernel_size=3)
        self.maxpool1 = nn.MaxPool2d(kernel_size=(2,1), stride=5)
        
        # third block
        self.conv_2 = nn.Conv2d(64, 128, padding=1, kernel_size=3)
        self.maxpool2 = nn.MaxPool2d(kernel_size=(4,3), stride=5)
        
        # fourth block
        self.conv_3 = nn.Conv2d(128, 64, padding=1, kernel_size=3)
        self.maxpool3 = nn.MaxPool2d(2, 2)
        
        # fifth block
        self.conv_4 = nn.Conv2d(64, 32, padding=1, kernel_size=3)
        self.maxpool4 = nn.MaxPool2d(1, 1)
        
        self.fc1 = nn.Linear(32, 1024)
        self.fc2 = nn.Linear(1024, 2)
        self.dropout = nn.Dropout(p=0.2)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        #residual = x
        
        # first block
        out = self.conv(x)
        out = self.relu(out)
        out = self.maxpool(out)
        #print(out.shape)
        
        # second block
        out = self.conv_1(out)
        out = self.relu(out)
        out = self.maxpool1(out)
        #print(out.shape)

        # third block
        out = self.conv_2(out)
        out = self.relu(out)
        out = self.maxpool2(out)
        #print(out.shape)

        # fourth block
        out = self.conv_3(out)
        out = self.relu(out)
        out = self.maxpool3(out)
        #print(out.shape)
        
        # fourth block
        out = self.conv_4(out)
        out = self.relu(out)
        out = self.maxpool4(out)
        #print(out.shape)

        out = out.view(-1, 32)
        out = self.dropout(self.relu(self.fc1(out)))
        out = self.fc2(out)
        #print(out.shape)

        return out

# %%
bell_cnn = BellCNN()
bell_cnn.cuda()
train(bell_cnn, train_dataset, num_epochs=100, batch_size=32, learning_rate=1e-4)
# Out:
# Epoch 1; Train Loss 0.649083; Val Loss 0.638433; Train Acc 0.621212; Val Acc 0.848837
# Epoch 11; Train Loss 0.678886; Val Loss 0.521618; Train Acc 0.621212; Val Acc 0.848837
# Epoch 21; Train Loss 0.513654; Val Loss 0.675174; Train Acc 0.808081; Val Acc 0.686047
# Epoch 31; Train Loss 0.659776; Val Loss 0.985682; Train Acc 0.886364; Val Acc 0.709302
# Epoch 41; Train Loss 0.118224; Val Loss 0.963697; Train Acc 0.969697; Val Acc 0.767442
# Epoch 51; Train Loss 0.013573; Val Loss 1.348697; Train Acc 0.934343; Val Acc 0.837209
# Epoch 61; Train Loss 0.008151; Val Loss 1.481569; Train Acc 0.992424; Val Acc 0.837209
# Epoch 71; Train Loss 0.027729; Val Loss 2.117370; Train Acc 1.000000; Val Acc 0.848837
# Epoch 81; Train Loss 0.006204; Val Loss 2.194415; Train Acc 1.000000; Val Acc 0.837209
# Epoch 91; Train Loss 0.001211; Val Loss 2.350822; Train Acc 1.000000; Val Acc 0.837209
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.8372093023255814

# %%
inlayer = torch.randn([8,256,3,6,6])
maxpool = nn.MaxPool3d(kernel_size=(2,2,2), padding=(1,0,0), stride=2)
layer = maxpool(inlayer)
print(layer.shape)

# %%
torch.cuda.empty_cache()

# %%
for param in paper_model.parameters():
    print(param.grad.data.sum())

# %%
get_accuracy(bell_cnn, train=False)

# %%
output = paper_model()
